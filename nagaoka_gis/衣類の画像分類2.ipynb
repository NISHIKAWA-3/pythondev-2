# %%
#①データ準備
from tensorflow.keras.datasets import fashion_mnist 
from tensorflow.keras.utils import to_categorical

# データ読み込み
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
# 正規化（0〜1の範囲に）
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# CNNの入力に合わせて形を変更（チャネル次元を追加）
x_train = x_train.reshape(-1, 28, 28, 1) 
x_test = x_test.reshape(-1, 28, 28, 1)

# %%
# ラベルをone-hot化
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
#②モデル構築(cnn)

from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
   Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
   MaxPooling2D(2,2),

   Conv2D(64, (3,3), activation='relu'),
   MaxPooling2D(2,2),

   Flatten(),
   Dense(128, activation='relu'),
   Dropout(0.5),
   Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])
# Out:
# /Users/m-kikuch/Downloads/pythondev 2/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#④学習
history = model.fit(
   x_train, y_train,
   epochs=10,
   batch_size=64,
   validation_split=0.2
)
# Out:
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7751 - loss: 0.6221 - val_accuracy: 0.8495 - val_loss: 0.4064
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.8537 - loss: 0.4114 - val_accuracy: 0.8702 - val_loss: 0.3453
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8687 - loss: 0.3639 - val_accuracy: 0.8831 - val_loss: 0.3163
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.8827 - loss: 0.3244 - val_accuracy: 0.8943 - val_loss: 0.2907
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.8916 - loss: 0.2986 - val_accuracy: 0.9015 - val_loss: 0.2713
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.8979 - loss: 0.2815 - val_accuracy: 0.9002 - val_loss: 0.2711
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9039 - loss: 0.2651 - val_accuracy: 0.9077 - val_loss: 0.2523
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9079 - loss: 0.2483 - val_accuracy: 0.9096 - val_loss: 0.2485
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9142 - loss: 0.2332 - val_accuracy: 0.9116 - val_loss: 0.2439
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9166 - loss: 0.2259 - val_accuracy: 0.9125 - val_loss: 0.2418

# %%
#⑤評価
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"テスト正解率: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9067 - loss: 0.2580
# テスト正解率: 0.9067

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import japanize_matplotlib  # 日本語フォント対応
